# %%
from pathlib import Path
import pandas as pd
import datetime

# %%
""" "
"To get datasets with original files already saved

kubectl exec -it <podname> -- /bin/bash
cd /xyz/original
./find_dataset_ids.sh
exit
podname
kubectl cp "$podname:/xyz/original/dataset_ids_2025_07_09.csv" ./dataset_ids_2025_07_09.csv
"""
today = datetime.datetime.now().strftime("%Y_%m_%d")
! kubectl cp "$podname:/xyz/original/dataset_ids_{today}.csv" ./dataset_ids_{today}.csv


current_ds_ids = pd.read_csv(f"dataset_ids_{today}.csv", header=None)
# Out:
# tar: Removing leading `/' from member names

# %%
today = datetime.datetime.now().strftime("%Y_%m_%d")
current_ds_ids = pd.read_csv(f"dataset_ids_{today}.csv", header=None)

# %%
current_ds_ids.shape
# Out:
# (435, 1)

# %%
import datetime

ds_ids = spark.table("ndb.`colabfit-prod`.prod.ds").select("id").collect()
ds_ids = [x.id for x in ds_ids]
today = datetime.datetime.now().strftime("%Y_%m_%d")

with open(f"dataset_ids_in_prod_{today}.csv", "w") as f:
    f.writelines([f"{x}\n" for x in ds_ids])

# %%
wip_ds_ids.shape
# Out:
# (435, 1)

# %%
wip_ds_ids = pd.read_csv(f"dataset_ids_in_prod_{today}.csv", header=None)
# original_ds_ids = pd.read_csv(f"dataset_ids_{today}.csv", header=None)

missing = list(set(wip_ds_ids[0]) - set(current_ds_ids[0]))
print(len(missing))
missing
# Out:
# 0
# []

# %%
"""
ls -a DS_s6gf4z2hcjqy_0/ | grep "->"
rm ./DS_s6gf4z2hcjqy_0/DS_s6gf4z2hcjqy_0.tar.xz

cp ./

"""

# %%
missing = [
    "DS_6pieq95jrqpn_0",
    "DS_xnio123pebli_0",
    "DS_s6gf4z2hcjqy_0",
    "DS_6qqf55wad1mv_0",
]

# %%
import pyspark.sql.functions as sf
from ast import literal_eval

miss = (
    spark.table("ndb.`colabfit-prod`.prod.ds")
    .filter(sf.col("id").isin(missing))
    .select("id", "name", "links")
)
miss2 = [
    (x["id"], x["name"], literal_eval(x["links"])["source-data"])
    for x in miss.collect()
]
print(*miss2, sep="\n")
# Out:
# 13

# %%
("DS_lcjsp7ctc1hy_0", "OMol25_validation", "https://huggingface.co/facebook/OMol25")
("DS_k8m3sm6ves4u_0", "OMol25_train_4M", "https://huggingface.co/facebook/OMol25")
(
    "DS_51sddg3b1bp1_0",
    "OMol25_neutral_validation",
    "https://huggingface.co/facebook/OMol25",
)
("DS_izdsom1hklzv_0", "OMol25_train_neutral", "https://huggingface.co/facebook/OMol25")
("DS_bzcf331ql8ji_0", "OMol25_train", "https://huggingface.co/facebook/OMol25")
# Out:
# 351

# %%
df = pd.DataFrame(
    [
        (
            "DS_s6gf4z2hcjqy_0",
            "Alexandria_geometry_optimization_paths_PBE_3D",
            "https://alexandria.icams.rub.de/",
        ),
        (
            "DS_xnio123pebli_0",
            "Alexandria_geometry_optimization_paths_PBE_1D",
            "https://alexandria.icams.rub.de/",
        ),
        (
            "DS_6pieq95jrqpn_0",
            "Alexandria_geometry_optimization_paths_PBE_2D",
            "https://alexandria.icams.rub.de/",
        ),
        ("DS_6qqf55wad1mv_0", "PropMolFlow_QM9_CNOFH_2025", None),
    ],
    columns=["id", "name", "links"],
)

# %%
df = pd.read_csv("data_by_id/dataset_name_id_links.csv", names=["name", "id", "links"])

# %% [markdown]
# #### Run from python shell inside ny-dev container

# %%
t = df.iterrows()
for i in t:
    p = Path("/xyz/original") / i[1]["id"]
    print(p)
    try:
        p.mkdir()
        filename = p / f"{i[1]['name']}.txt"
        filename.touch()
        if not filename.exists():
            print(filename)
    except:
        print(f"Failed to create {i[1]['name']} ", f"for {i[1]['id']}")
# Out:
# data_by_id/Alexandria_geometry_optimization_paths_PBE_3D
# data_by_id/Alexandria_geometry_optimization_paths_PBE_1D
# data_by_id/Alexandria_geometry_optimization_paths_PBE_2D
# data_by_id/PropMolFlow_QM9_CNOFH_2025

# %%
from pathlib import Path


def move_and_symlink(file_location, directories):
    file_path = Path(file_location)
    new_location = Path(directories[0]) / file_path.name
    try:
        # Move the file to the new location
        new_location.parent.mkdir(parents=True, exist_ok=True)
        file_path.rename(new_location)
    except Exception as e:
        print(f"Failed to move {file_path} to {new_location}: {e}")
        return
    # Create symlinks in the other directories
    for directory in directories[1:]:
        symlink_path = Path(directory) / file_path.name
        try:
            # symlink_path.parent.mkdir(parents=True, exist_ok=True)
            symlink_path.symlink_to(os.path.relpath(new_location, symlink_path.parent))
        except Exception as e:
            print(f"Failed to create symlink at {symlink_path}: {e}")


file_location = "path/to/your/file.txt"
directories = ["path/to/new/location", "path/to/symlink1", "path/to/symlink2"]
move_and_symlink(file_location, directories)

# %%
"""OC22-IS2RE-Train	DS_3h39eqiv9urv_0
OC22-IS2RE-Validation-in-domain	DS_4eb78xs9suoo_0
OC22-IS2RE-Validation-out-of-domain	DS_ikbqbyd3dw25_0
OC22-S2EF-Train	DS_jgaid7espcoc_0
OC22-S2EF-Validation-in-domain	DS_f25kywgtdhks_0
OC22-S2EF-Validation-out-of-domain	DS_y8u933mhadjf_0"""

directories = [
    "DS_3h39eqiv9urv_0",
    "DS_4eb78xs9suoo_0",
    "DS_ikbqbyd3dw25_0",
    "DS_jgaid7espcoc_0",
    "DS_f25kywgtdhks_0",
    "DS_y8u933mhadjf_0",
]
file_location = "/persistent/colabfit_raw_data/data_by_id/DS_3h39eqiv9urv_0/oc22.tar.xz"
move_and_symlink(file_location, directories)

# %%
[
    "DS_gt0oa9fngod7_0",
    "DS_e22u3j5sbilx_0",
    "DS_632yputkfhpg_0",
    "DS_8gqwz5bw1pvq_0",
    "DS_0xfqsnoawhoo_0",
    "DS_ztlvjmuwskom_0",
    "DS_k0rexhnv58vn_0",
]

# %%
df = pd.read_csv("dataset_name_id_links.csv", names=["name", "id", "links"])

# %% [markdown]
# ## Python function for moving files

# %%
import subprocess
from pathlib import Path


def move_file(current, id, ds_name):
    current = Path(current)
    dest = Path("/xyz/original") / id
    if not dest.exists():
        print(f"Destination path {dest} does not exist. Creating...")
        dest.mkdir(parents=True)
    try:
        assert dest.exists(), f"Destination path {dest} does not exist."
        assert current.exists(), f"Source file {current} does not exist."
        tar_path = dest / (id + ".tar.xz")
        assert not tar_path.exists(), f"Destination tarball {tar_path} already exists."
        with open(dest / f"{ds_name}.txt", "w") as f:
            f.write(f"{ds_name}\n")
        # Build the tar command
        command = [
            "tar",
            "-cJf",
            str(tar_path),
            "-C",
            str(current.parent),
            str(current.name),
        ]
        # Run the tar process asynchronously
        subprocess.Popen(command, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
        print(f"Submitted compression of {current} to {tar_path}.")
    except Exception as e:
        print(f"Failed to move and compress {current} to {dest}: {e}")

# %% [markdown]
# ## Files moved new, inside Kubernetes pod

# %%
"""
('DS_6nu6i240an78_0', 'OMat24_train_rattled_1000_subsampled', 'https://fair-chem.github.io/core/datasets/omat24.html')
('DS_96l9f8z75uof_0', 'OMat24_train_rattled_relax', 'https://fair-chem.github.io/core/datasets/omat24.html')
('DS_jcodhqs0atqm_0', 'OMat24_train_rattled_300', 'https://fair-chem.github.io/core/datasets/omat24.html')
('DS_z0545ougitpp_0', 'OMat24_train_rattled_500_subsampled', 'https://fair-chem.github.io/core/datasets/omat24.html')
('DS_t8iygwyagbaj_0', 'OMat24_train_rattled_300_subsampled', 'https://fair-chem.github.io/core/datasets/omat24.html')
('DS_weq0x6qxqbau_0', 'OMat24_train_rattled_500', 'https://fair-chem.github.io/core/datasets/omat24.html')
('DS_jqrkc9e7cgmh_0', 'OMat24_train_aimd_from_PBE_1000_npt', 'https://fair-chem.github.io/core/datasets/omat24.html')
('DS_w0ra2olwcy29_0', 'OMat24_train_aimd_from_PBE_1000_nvt', 'https://fair-chem.github.io/core/datasets/omat24.html')
('DS_6xvvh8yl7rfd_0', 'OMat24_train_aimd_from_PBE_3000_npt', 'https://fair-chem.github.io/core/datasets/omat24.html')
('DS_fi9ozets1s5f_0', 'OMat24_train_aimd_from_PBE_3000_nvt', 'https://fair-chem.github.io/core/datasets/omat24.html')
('DS_opcbnu5xs3pe_0', 'OMat24_train_rattled_1000', 'https://fair-chem.github.io/core/datasets/omat24.html')
('DS_2oy3ipc8qxa7_0', 'sAlex_validation', 'https://fair-chem.github.io/core/datasets/omat24.html')
('DS_gxjhn6vdjnxg_0', 'sAlex_train', 'https://fair-chem.github.io/core/datasets/omat24.html')
"""

# %%
"""
mkdir ../DS_w0ra2olwcy29_0
touch ../DS_w0ra2olwcy29_0/OMat24_train_aimd_from_PBE_1000_nvt.txt
tar -cJf ../DS_w0ra2olwcy29_0/DS_w0ra2olwcy29_0.tar.xz aimd-from-PBE-1000-nvt &

mkdir ../DS_6xvvh8yl7rfd_0
touch ../DS_6xvvh8yl7rfd_0/OMat24_train_aimd_from_PBE_3000_npt.txt
tar -cJf ../DS_6xvvh8yl7rfd_0/DS_6xvvh8yl7rfd_0.tar.xz aimd-from-PBE-3000-npt &

mkdir ../DS_fi9ozets1s5f_0
touch ../DS_fi9ozets1s5f_0/OMat24_train_aimd_from_PBE_3000_nvt.txt
tar -cJf ../DS_fi9ozets1s5f_0/DS_fi9ozets1s5f_0.tar.xz aimd-from-PBE-3000-nvt &

mkdir ../DS_opcbnu5xs3pe_0
touch ../DS_opcbnu5xs3pe_0/OMat24_train_rattled_1000.txt
tar -cJf ../DS_opcbnu5xs3pe_0/DS_opcbnu5xs3pe_0.tar.xz rattled-1000 &

mkdir ../DS_s6gf4z2hcjqy_0
touch ../DS_s6gf4z2hcjqy_0/Alexandria_geometry_optimization_paths_PBE_3D.txt
tar -cJf ../DS_s6gf4z2hcjqy_0/DS_s6gf4z2hcjqy_0.tar.xz alexandria


"""

# %%
"""mkdir ../DS_6nu6i240an78_0
touch ../DS_6nu6i240an78_0/OMat24_train_rattled_1000_subsampled.txt
tar -cJf ../DS_6nu6i240an78_0/DS_6nu6i240an78_0.tar.xz rattled-1000-subsampled &


mkdir ../DS_96l9f8z75uof_0
touch ../DS_96l9f8z75uof_0/OMat24_train_rattled_relax.txt
tar -cJf ../DS_96l9f8z75uof_0/DS_96l9f8z75uof_0.tar.xz rattled-relax &

mkdir ../DS_jcodhqs0atqm_0
touch ../DS_jcodhqs0atqm_0/OMat24_train_rattled_300.txt
tar -cJf ../DS_jcodhqs0atqm_0/DS_jcodhqs0atqm_0.tar.xz rattled-300 &

mkdir ../DS_z0545ougitpp_0
touch ../DS_z0545ougitpp_0/OMat24_train_rattled_500_subsampled.txt
tar -cJf ../DS_z0545ougitpp_0/DS_z0545ougitpp_0.tar.xz rattled-500-subsampled &

mkdir ../DS_t8iygwyagbaj_0
touch ../DS_t8iygwyagbaj_0/OMat24_train_rattled_300_subsampled.txt
tar -cJf ../DS_t8iygwyagbaj_0/DS_t8iygwyagbaj_0.tar.xz rattled-300-subsampled &

mkdir ../DS_weq0x6qxqbau_0
touch ../DS_weq0x6qxqbau_0/OMat24_train_rattled_500.txt
tar -cJf ../DS_weq0x6qxqbau_0/DS_weq0x6qxqbau_0.tar.xz rattled-500 &

mkdir ../DS_jqrkc9e7cgmh_0
touch ../DS_jqrkc9e7cgmh_0/OMat24_train_aimd_from_PBE_1000_npt.txt
tar -cJf ../DS_jqrkc9e7cgmh_0/DS_jqrkc9e7cgmh_0.tar.xz aimd-from-PBE-1000-npt &

mkdir ../DS_2oy3ipc8qxa7_0
touch ../DS_2oy3ipc8qxa7_0/sAlex_validation.txt
tar -cJf ../DS_2oy3ipc8qxa7_0/DS_2oy3ipc8qxa7_0.tar.xz sAlex_validation &
"""

# %%
move_file("/xyz/original/salex/train", "DS_gxjhn6vdjnxg_0", "sAlex_train")

move_file("/xyz/original/salex/val", "DS_2oy3ipc8qxa7_0", "sAlex_validation")

# %% [markdown]
# ## Files moved

# %%
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/BOTNet/BOTNet-datasets-main/dataset_acac/isolated_atoms.xyz",
    "DS_e22u3j5sbilx_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/BOTNet/BOTNet-datasets-main/dataset_acac/train_300K.xyz",
    "DS_8gqwz5bw1pvq_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/BOTNet/BOTNet-datasets-main/dataset_acac/test_H_transfer.xyz",
    "DS_ztlvjmuwskom_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/BOTNet/BOTNet-datasets-main/dataset_acac/test_dihedral.xyz",
    "DS_0xfqsnoawhoo_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/BOTNet/BOTNet-datasets-main/dataset_acac/test_MD_300K.xyz",
    "DS_gt0oa9fngod7_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/BOTNet/BOTNet-datasets-main/dataset_acac/train_600K.xyz",
    "DS_632yputkfhpg_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/BOTNet/BOTNet-datasets-main/dataset_acac/test_MD_600K.xyz",
    "DS_k0rexhnv58vn_0",
)

# %%
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/ani-al/ani-al-master/data/",
    "DS_tz8gsj3xi2g4_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/ani-al/ani-al-master/model/model-Al-75/testset",
    "DS_bnnyjpaqb09i_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/ANI1x/ANI1x.h5", "DS_ko3rpzre7bea_0"
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/AlNiCu_Berk/", "DS_vmnudsz7kx0a_0"
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/ABC2D6-16/abc2d6-16/",
    "DS_0ady7a8a8n6p_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/BA10-18/ba10-18.xyz",
    "DS_lifzo8zpa76m_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/C_allotropes_MingjianEllad/carbon_energies_forces/",
    "DS_zn8tf2kmgrdm_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/Carbon_GAP_20/Carbon_GAP_20/Carbon_GAP_20_Training_Set.xyz",
    "DS_sz9me9r61581_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/Carbon_GAP_20/Carbon_GAP_20/Carbon_Data_Set_Total.xyz",
    "DS_on6fusdw5n8q_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/NMD_18/source/", "DS_of1clsgf4nab_0"
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/PtNi_alloy_dft_Han/PtNi_alloy_dft.db/",
    "DS_l3xhsrlgu8tq_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/QM9x/qm9x.h5", "DS_d5ug96vla5xy_0"
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/SN2_UnkeOliverMeuwly/sn2_reactions.npz",
    "DS_3tspv1150ejj_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/Si_Berk/source/",
    "DS_paehju6qhaym_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/Solvated_protein_UnkeOliverMeuwly/solvated_protein_fragments.npz",
    "DS_ctjgc03xdauc_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/TiO2_Berk/TiO2.extxyz",
    "DS_kvjft3au55qb_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/Ti_Mo_alloys_SilvaAndrea/dataset/",
    "DS_jn819esw58ah_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/W-14/w-14.xyz", "DS_kk4a8u1eo42m_0"
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/agpd/agpd-master/data/",
    "DS_y5m3hunroa7x_0",
)

# %%
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/md_22/source/md22_buckyball-catcher.xyz",
    "DS_7g8q68fszjvs_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/md_22/source/md22_AT-AT.xyz",
    "DS_eqt5dbhsmm68_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/md_22/source/md22_stachyose.xyz",
    "DS_87ojug1k96ef_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/md_22/source/md22_Ac-Ala3-NHMe.xyz",
    "DS_l6awe3jnivnm_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/md_22/source/md22_double-walled_nanotube.xyz",
    "DS_d92bnafzwynr_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/md_22/source/md22_AT-AT-CG-CG.xyz",
    "DS_rx1ei5q0x9gy_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/md_22/source/md22_DHA.xyz",
    "DS_xwmthngerf71_0",
)

# %%
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/rmd17/rmd17/npz_data/",
    "DS_8rafgy0ly6bt_0",
)

# %%
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/sGDML/source/malonaldehyde_ccsd_t-train.xyz",
    "DS_201vhvywll83_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/sGDML/source/benzene_ccsd_t-train.xyz",
    "DS_8xk0v5v9dbx0_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/sGDML/source/benzene2018_dft_FHI-aims.xyz",
    "DS_q9y1aat05u42_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/sGDML/source/toluene_ccsd_t-test.xyz",
    "DS_ega58h2u9rwr_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/sGDML/source/benzene_ccsd_t-test.xyz",
    "DS_jol8dvjej92n_0	",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/sGDML/source/aspirin_ccsd-test.xyz",
    "DS_4e7a9g2kav0a_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/sGDML/source/toluene_ccsd_t-train.xyz",
    "DS_o8ssxj2re4kx_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/sGDML/source/malonaldehyde_ccsd_t-test.xyz",
    "DS_yw3sqtaq40ll_0	",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/sGDML/source/ethanol_ccsd_t-test.xyz",
    "DS_iavvqpb14zqv_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/sGDML/source/ethanol_ccsd_t-train.xyz",
    "DS_dalgmbg32lwz_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/sGDML/source/aspirin_ccsd-train.xyz",
    "DS_xy48avqcknnk_0",
)

# %%
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/nenci2021/nenci2021/",
    "DS_0j2smy6relq0_0",
)

move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/COLL/coll_v1.2_AE_test.xyz",
    "DS_anwiyxoek66t_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/COLL/coll_v1.2_AE_train.xyz",
    "DS_cifhpgzw3ckj_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/COLL/coll_v1.2_AE_val.xyz",
    "DS_1y25o4zvyfm0_0",
)

move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/HME21/train/",
    "DS_jhfis7syauhm_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/HME21/val/", "DS_vf8hkwxhibio_0"
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/HME21/test/",
    "DS_cpgyq72fs7uk_0",
)

# %%
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/saidi_23_dnps/Training_Data/",
    "DS_whwcq2rzt2of_0",
)

move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/saidi_23_dnps/Training_Data/Ag/",
    "DS_q4h7q8q0fnve_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/saidi_23_dnps/Training_Data/Al/",
    "DS_8y775we7um7w_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/saidi_23_dnps/Training_Data/Au/",
    "DS_iie3c31ar46x_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/saidi_23_dnps/Training_Data/Co/",
    "DS_jt0lax9yd15r_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/saidi_23_dnps/Training_Data/Cu/",
    "DS_dc3o40aou2le_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/saidi_23_dnps/Training_Data/Ge/",
    "DS_90fnsmavv1am_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/saidi_23_dnps/Training_Data/I/",
    "DS_gc1y80tpyylb_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/saidi_23_dnps/Training_Data/Kr/",
    "DS_omnl1yy49sdh_0",
)

move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/saidi_23_dnps/Training_Data/Li/",
    "DS_wyo91w20wlgm_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/saidi_23_dnps/Training_Data/Mg/",
    "DS_mevqyitwxukc_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/saidi_23_dnps/Training_Data/Mo/",
    "DS_bjkftn0ug9r3_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/saidi_23_dnps/Training_Data/Nb/",
    "DS_zbxayq0diq6l_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/saidi_23_dnps/Training_Data/Ni/",
    "DS_nue14kckbkdh_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/saidi_23_dnps/Training_Data/Os/",
    "DS_098x6q7kbeat_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/saidi_23_dnps/Training_Data/Pb/",
    "DS_k065jfggbq43_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/saidi_23_dnps/Training_Data/Pd/",
    "DS_g0sb0h7usqw7_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/saidi_23_dnps/Training_Data/Pt/",
    "DS_0zgz34a90a6i_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/saidi_23_dnps/Training_Data/Re/",
    "DS_gzbvdicu231p_0",
)

move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/saidi_23_dnps/Training_Data/Sb/",
    "DS_z90lfjg88fzo_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/saidi_23_dnps/Training_Data/Sr/",
    "DS_o3itca7mk80r_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/saidi_23_dnps/Training_Data/Ti/",
    "DS_ofpcyxez6xsc_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/saidi_23_dnps/Training_Data/Zn/",
    "DS_xsad0btc0bsn_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/saidi_23_dnps/Training_Data/Zr/",
    "DS_h9w8v7289utq_0",
)

# %%
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/carolina_materials/carolina_matdb/",
    "DS_r2r8k3fyb6ny_0",
)

move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/benzene_succinic_acid_glycine/benzene_test_QE_PBE_TS.xyz",
    "DS_23820czfaq24_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/benzene_succinic_acid_glycine/benzene_train_FPS_QE_PBE_TS.xyz",
    "DS_3qi25f3sxkwr_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/benzene_succinic_acid_glycine/benzene_val_QE_PBE_TS.xyz",
    "DS_8ou78o18mvfz_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/benzene_succinic_acid_glycine/benzene_test_AIMS_PBE0_MBD.xyz",
    "DS_ech19sh1koj4_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/benzene_succinic_acid_glycine/benzene_train_FPS_AIMS_PBE0_MBD.xyz",
    "DS_ce4zytu7ph7e_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/benzene_succinic_acid_glycine/benzene_val_AIMS_PBE0_MBD.xyz",
    "DS_xaq6jwha0a7o_0",
)

move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/benzene_succinic_acid_glycine/glycine_test_QE_PBE_TS.xyz",
    "DS_qx4h8j4luk70_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/benzene_succinic_acid_glycine/glycine_train_FPS_QE_PBE_TS.xyz",
    "DS_op9kvcm7ui6l_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/benzene_succinic_acid_glycine/glycine_val_QE_PBE_TS.xyz",
    "DS_052bb0zufjaz_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/benzene_succinic_acid_glycine/glycine_test_AIMS_PBE0_MBD.xyz",
    "DS_h3jymhr74qv4_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/benzene_succinic_acid_glycine/glycine_train_FPS_AIMS_PBE0_MBD.xyz",
    "DS_b1n228x610dj_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/benzene_succinic_acid_glycine/glycine_val_AIMS_PBE0_MBD.xyz",
    "DS_n1nilf7ralhq_0",
)

# %%
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/alox_jcp2020/",
    "DS_70btumen3361_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/lml_retrain/bulk_MD_test.xyz",
    "DS_0od3fns1ap8a_0",
)

move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/WS22_database/ws22_acrolein.npz",
    "DS_wqezpu0pw9io_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/WS22_database/ws22_alanine.npz",
    "DS_vxtsip8qgm7t_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/WS22_database/ws22_dmabn.npz",
    "DS_srva1ami36vs_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/WS22_database/ws22_nitrophenol.npz",
    "DS_s3qsg4c3hyk6_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/WS22_database/ws22_o-hbdi.npz",
    "DS_ukw33o4tvaiy_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/WS22_database/ws22_sma.npz",
    "DS_jz8yny1m7xer_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/WS22_database/ws22_thymine.npz",
    "DS_ngd7bajt6nvx_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/WS22_database/ws22_toluene.npz",
    "DS_ztubsom32o4f_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/WS22_database/ws22_urea.npz",
    "DS_0upwmrh3apql_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/WS22_database/ws22_urocanic.npz",
    "DS_w3sximoit8bj_0",
)

move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/flexible_molecules/Datasets/",
    "DS_i23sbm1o45sj_0",
)

move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/co_dimer_jpca_2022/data/",
    "DS_uwqpfuuj6utw_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/co_dimer_jpca_2022/data/",
    "DS_doo9ltj3vsnu_0",
)

# %%
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/DS_gjr8gi1tb8wh_0/final_h5/",
    "DS_gjr8gi1tb8wh_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/DS_yxeu6us2i6dh_0/final_h5/",
    "DS_yxeu6us2i6dh_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/DS_yxeu6us2i6dh_0/final_h5/",
    "DS_yxeu6us2i6dh_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/DS_wxf8f3t3abul_0/final_h5/",
    "DS_wxf8f3t3abul_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/water_ice_nep/", "DS_wm2xs5bhyzcx_0"
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/water_ice_pnas/",
    "DS_mz0vl4zs7bex_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/water_ice_jcp/", "DS_p2aaxa2vfnr6_0"
)

move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/ac_jcp_2023/", "DS_bmjfal3bj4ah_0"
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/ac_jcp_2023/aCdataset-zenodo/dataset_train_test_split/test.xyz",
    "DS_sany2behzwv8_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/ac_jcp_2023/aCdataset-zenodo/dataset_train_test_split/train.xyz",
    "DS_20h8o5d0ltx1_0",
)

move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/adatoms_on_graphene/DFT_data",
    "DS_08feepssbuq5_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/CHON_berk/", "DS_3td9plyix4ib_0"
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets/C_allotropes_MingjianEllad/",
    "DS_zn8tf2kmgrdm_0",
)
move_file("/persistent/colabfit_raw_data/new_raw_datasets/tmQM/", "DS_qde4v70hhmmj_0")
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/OrbNet_Denali/",
    "DS_5obi9nxcgmof_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/q-aqua/", "DS_p9qjlc9l8scx_0"
)

move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/q-aqua/", "DS_dqascvm2baak_0"
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/q-aqua/", "DS_swqa99vqo249_0"
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/silica_npjcm_2022/",
    "DS_14m394gnh3ae_0",
)

# %%
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/xxmd_test/xxMD-CASSCF//",
    "DS_sytg0385f79a_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/xxmd_train/xxMD-CASSCF/",
    "DS_qvljl3vtdp0f_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/xxmd_val/xxMD-CASSCF/",
    "DS_e0nl35x6dl85_0",
)

move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/xxmd_test/xxMD-DFT/",
    "DS_q007ninsdjvf_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/xxmd_train/xxMD-DFT/",
    "DS_fblez5twbr07_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/xxmd_val/xxMD-DFT/",
    "DS_d1nmrzy4csx1_0",
)

move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/sialti_seko_prb_2019_test",
    "DS_dqascvm2baak_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/sialti_seko_prb_2019_train",
    "DS_swqa99vqo249_0",
)

move_file(
    "/persistent/colabfit_raw_data/chig_aimd/AIMD-Chig-random",
    "DS_e08dhew7z0r6_0",
)
move_file(
    "/persistent/colabfit_raw_data/chig_aimd/AIMD-Chig-random",
    "DS_dsikv10na4f8_0",
)
move_file(
    "/persistent/colabfit_raw_data/chig_aimd/AIMD-Chig-random",
    "DS_u0ggh1iie0uc_0",
)

move_file(
    "/persistent/colabfit_raw_data/chig_aimd/AIMD-Chig-scaffold",
    "DS_zmzkyvep8l55_0",
)
move_file(
    "/persistent/colabfit_raw_data/chig_aimd/AIMD-Chig-scaffold",
    "DS_7puixss6qd61_0",
)
move_file(
    "/persistent/colabfit_raw_data/chig_aimd/AIMD-Chig-scaffold",
    "DS_mzz13lim5qfi_0",
)

# %%
# JARVIS

move_file(
    "/persistent/colabfit_raw_data/jarvis/jarvis_json/AGRA_CHO.json",
    "DS_z3s0qui5vg5c_0",
)
move_file(
    "/persistent/colabfit_raw_data/jarvis/jarvis_json/AGRA_OH.json",
    "DS_osavzsrz5mgf_0",
)
move_file(
    "/persistent/colabfit_raw_data/jarvis/jarvis_json/mlearn.json",
    "DS_g9sra4y8efji_0",
)
move_file(
    "/persistent/colabfit_raw_data/jarvis/jarvis_json/tinnet_OH.json",
    "DS_mk2e641eop9w_0",
)
move_file(
    "/persistent/colabfit_raw_data/jarvis/jarvis_json/omdbv1.json",
    "DS_hrt0twm503tr_0",
)
move_file(
    "/persistent/colabfit_raw_data/jarvis/jarvis_json/CFID_OQMD_460k.json",
    "DS_u8strp7hm0cy_0",
)
move_file(
    "/persistent/colabfit_raw_data/jarvis/jarvis_json/AGRA_O.json",
    "DS_ikx8oaixaoz0_0",
)
move_file(
    "/persistent/colabfit_raw_data/jarvis/jarvis_json/all_mp.json",
    "DS_gpsibs9f47k4_0",
)
move_file(
    "/persistent/colabfit_raw_data/jarvis/jarvis_json/AGRA_COOH.json",
    "DS_bggn2p6qw8zv_0",
)
move_file(
    "/persistent/colabfit_raw_data/jarvis/jarvis_json/AGRA_CO.json",
    "DS_1ynp8v7d3er5_0",
)
move_file(
    "/persistent/colabfit_raw_data/jarvis/jarvis_json/ocp_all.json",
    "DS_3u17g7ukggi5_0",
)
move_file(
    "/persistent/colabfit_raw_data/jarvis/jarvis_json/ocp10k.json",
    "DS_6dcul0b17524_0",
)
move_file(
    "/persistent/colabfit_raw_data/jarvis/jarvis_json/ocp100k.json",
    "DS_armtbsouma25_0",
)
move_file(
    "/persistent/colabfit_raw_data/jarvis/jarvis_json/tinnet_O.json",
    "DS_ok9dbnj53zih_0",
)
move_file(
    "/persistent/colabfit_raw_data/jarvis/jarvis_json/tinnet_N.json",
    "DS_ffsgl0wufoft_0",
)
move_file(
    "/persistent/colabfit_raw_data/jarvis/jarvis_json/qm9_std_jctc.json",
    "DS_jz1q9juw7ycj_0",
)
move_file(
    "/persistent/colabfit_raw_data/jarvis/jarvis_json/jqe_tb_folder.json",
    "DS_e471qdt7c6db_0",
)
move_file(
    "/persistent/colabfit_raw_data/jarvis/jarvis_json/qmof_db.json",
    "DS_221svb9fxfk7_0",
)
move_file(
    "/persistent/colabfit_raw_data/jarvis/jarvis_json/jarvis_epc_data_2d.json",
    "DS_7jji22dy5hix_0",
)
move_file(
    "/persistent/colabfit_raw_data/jarvis/jarvis_json/snumat.json",
    "DS_1nbddfnjxbjc_0",
)

# %%
"""
hopv_15.json      ssub.json  id_prop.json d2-12-12-2022.json
"""

move_file(
    "/persistent/colabfit_raw_data/jarvis/jarvis_json/CFID_mp_desc_data_84k.json",
    "DS_1s8172fnm2ct_0",
)
move_file(
    "/persistent/colabfit_raw_data/jarvis/jarvis_json/jdft_3d-8-18-2021.json",
    "DS_soziqjohq6hm_0",
)
move_file(
    "/persistent/colabfit_raw_data/jarvis/jarvis_json/jdft_3d-12-12-2022.json",
    "DS_t02h9eraswtv_0",
)
move_file(
    "/persistent/colabfit_raw_data/jarvis/jarvis_json/d2-3-12-2021.json",
    "DS_4ml1yrigmar0_0",
)
move_file(
    "/persistent/colabfit_raw_data/jarvis/jarvis_json/c2db_atoms.json",
    "DS_8hgxhsfkcfa7_0",
)
move_file(
    "/persistent/colabfit_raw_data/jarvis/jarvis_json/all_oqmd.json",
    "DS_untxw8nljf92_0",
)
move_file(
    "/persistent/colabfit_raw_data/jarvis/jarvis_json/megnet.json",
    "DS_9yr94hhj1k33_0",
)
move_file(
    "/persistent/colabfit_raw_data/jarvis/jarvis_json/cfid_3d-8-18-2021.json",
    "DS_np1noc8iip47_0",
)
move_file(
    "/persistent/colabfit_raw_data/jarvis/jarvis_json/twodmatpd.json",
    "DS_hdv6si8yu2mv_0",
)
move_file(
    "/persistent/colabfit_raw_data/jarvis/jarvis_json/pgnome.json",
    "DS_dbgckv1il6v7_0",
)
move_file(
    "/persistent/colabfit_raw_data/jarvis/jarvis_json/jarvis_alignn.json",
    "DS_720rbshv96l1_0",
)
move_file(
    "/persistent/colabfit_raw_data/jarvis/jarvis_json/megnet-mp-2019-04-01.json",
    "DS_5ar73nonq6l1_0",
)
move_file(
    "/persistent/colabfit_raw_data/jarvis/jarvis_json/qm9_dgl.json",
    "DS_tat5i46x3hkr_0",
)

# %%
"""./CGM-MLP-Cr-C:
Training_Dataset_deposition.xyz

./CGM-MLP-Cu-C:
Training_Dataset_deposition.xyz  Training_Dataset_metal_surface.xyz

./CGM-MLP-Cu-C-O:
Training_Dataset_Cu-C-O.xyz  Training_Dataset_deposition.xyz

./CGM-MLP-Ti-C:
Training_Dataset_deposition.xyz
"""

move_file(
    "/persistent/colabfit_raw_data/CGM_MLP/GAP-20",
    "DS_qslbmhe4bcgg_0",
)
move_file(
    "/persistent/colabfit_raw_data/CGM_MLP/CGM-MLP-Cr-C/Training_Dataset_deposition.xyz",
    "DS_392q5d027yja_0",
)
move_file(
    "/persistent/colabfit_raw_data/CGM_MLP/CGM-MLP-Cu-C/Training_Dataset_deposition.xyz",
    "DS_vgy50b4qz4p7_0",
)
move_file(
    "/persistent/colabfit_raw_data/CGM_MLP/CGM-MLP-Cu-C/Training_Dataset_metal_surface.xyz",
    "DS_mo7q9ajg1lw8_0",
)
move_file(
    "/persistent/colabfit_raw_data/CGM_MLP/CGM-MLP-Cu-C-O/Training_Dataset_Cu-C-O.xyz",
    "DS_xho213jy5pf9_0",
)
move_file(
    "/persistent/colabfit_raw_data/CGM_MLP/CGM-MLP-Cu-C-O/Training_Dataset_deposition.xyz",
    "DS_xzo1tvni8bay_0",
)
move_file(
    "/persistent/colabfit_raw_data/CGM_MLP/CGM-MLP-Ti-C/Training_Dataset_deposition.xyz",
    "DS_8frq3jczb0dt_0",
)

move_file(
    "/persistent/colabfit_raw_data/CGM_MLP/testing_screening_parameters/Amorphous_Carbon_Testing_Set.xyz",
    "DS_wt0m3lxcdy52_0",
)
move_file(
    "/persistent/colabfit_raw_data/CGM_MLP/testing_screening_parameters/Amorphous_Carbon_Training_Set.xyz",
    "DS_taxwl7jo4f8a_0",
)
move_file(
    "/persistent/colabfit_raw_data/CGM_MLP/testing_screening_parameters/Carbon_Cluster_Testing_Set.xyz",
    "DS_gkumjkncy8ft_0",
)
move_file(
    "/persistent/colabfit_raw_data/CGM_MLP/testing_screening_parameters/Carbon_Cluster_Training_Set.xyz",
    "DS_6sjhg1f8fv5j_0",
)
move_file(
    "/persistent/colabfit_raw_data/CGM_MLP/testing_screening_parameters/Deposited_Carbon_Testing_Set.xyz",
    "DS_5r9dvov8nq7c_0",
)
move_file(
    "/persistent/colabfit_raw_data/CGM_MLP/testing_screening_parameters/Deposited_Carbon_Training_Set.xyz",
    "DS_j6w4ru800ukq_0",
)
move_file(
    "/persistent/colabfit_raw_data/CGM_MLP/testing_screening_parameters/Graphite_Training_Set.xyz",
    "DS_jasbxoigo7r4_0",
)

# %%
# MLEARN
"""./Cu:
test.json  training.json

./Ge:
test.json  training.json

./Li:
test.json  training.json

./Mo:
  test.json  training.json

./Ni:
test.json  training.json

./Si:
test.json  training.json
"""

move_file(
    "/persistent/colabfit_raw_data/mlearn/Cu/test.json",
    "DS_xmgn3ofqzon9_0",
)
move_file(
    "/persistent/colabfit_raw_data/mlearn/Cu/training.json",
    "DS_3pv3hck35iy6_0",
)
move_file(
    "/persistent/colabfit_raw_data/mlearn/Ge/test.json",
    "DS_pyrk84w3auvb_0",
)
move_file(
    "/persistent/colabfit_raw_data/mlearn/Ge/training.json",
    "DS_ot3m0rxle8fs_0",
)
move_file(
    "/persistent/colabfit_raw_data/mlearn/Li/test.json",
    "DS_jf20mvwao5xi_0",
)
move_file(
    "/persistent/colabfit_raw_data/mlearn/Li/training.json",
    "DS_h7zao9ya9sd8_0",
)
move_file(
    "/persistent/colabfit_raw_data/mlearn/Mo/test.json",
    "DS_l0b6iq3no012_0",
)
move_file(
    "/persistent/colabfit_raw_data/mlearn/Mo/training.json",
    "DS_h7zao9ya9sd8_0",
)
move_file(
    "/persistent/colabfit_raw_data/mlearn/Ni/test.json",
    "DS_zjkz9664bapl_0",
)
move_file(
    "/persistent/colabfit_raw_data/mlearn/Ni/training.json",
    "DS_lfyd4jv627cr_0",
)
move_file(
    "/persistent/colabfit_raw_data/mlearn/Si/test.json",
    "DS_lvjng6g41bwy_0",
)
move_file(
    "/persistent/colabfit_raw_data/mlearn/Si/training.json",
    "DS_eltotrjoqonr_0",
)

# %%
"""./lisnps_sse_pbesol
./lisips_sse_pbesol
./lisips_sse_pbe
./ligeps_sse_pbe
./lisnps_sse_pbe
"""

move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/ligeps_sse_pbe",
    "DS_4lev0d7cs1yl_0",
)
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/lisips_sse_pbe",
    "DS_9p3sip4yhiju_0",
)
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/lisips_sse_pbesol",
    "DS_th9w66lyxspv_0",
)

# %%
"""SAIT
./HfO:
LICENSE.txt  OOD.xyz  Testset.xyz  Trainset.xyz  Validset.xyz

./HfO_raw:
Crystal  LICENSE.txt  OOD  Random

./HfO_raw/Crystal:
1.xyz  2.xyz  3.xyz  4.xyz  5.xyz

./HfO_raw/OOD:
11.xyz	12.xyz

./HfO_raw/Random:
10.xyz	6.xyz  7.xyz  8.xyz  9.xyz

./SiN:
LICENSE.txt  OOD.xyz  Testset.xyz  Trainset.xyz  Validset.xyz

./SiN_raw:
LICENSE.txt  N_Only  OOD_MeltQuenchRelax  SiN_compound	Si_Only

./SiN_raw/N_Only:
107.xyz  108.xyz  109.xyz  110.xyz

./SiN_raw/OOD_MeltQuenchRelax:
Melt.xyz  Quench.xyz  Relax.xyz

./SiN_raw/SiN_compound:
1.xyz	13.xyz	17.xyz	20.xyz	24.xyz	28.xyz	31.xyz	35.xyz	39.xyz	42.xyz	46.xyz	5.xyz	53.xyz	57.xyz	60.xyz	64.xyz	68.xyz	71.xyz	75.xyz	79.xyz	82.xyz	86.xyz	9.xyz
10.xyz	14.xyz	18.xyz	21.xyz	25.xyz	29.xyz	32.xyz	36.xyz	4.xyz	43.xyz	47.xyz	50.xyz	54.xyz	58.xyz	61.xyz	65.xyz	69.xyz	72.xyz	76.xyz	8.xyz	83.xyz	87.xyz	90.xyz
11.xyz	15.xyz	19.xyz	22.xyz	26.xyz	3.xyz	33.xyz	37.xyz	40.xyz	44.xyz	48.xyz	51.xyz	55.xyz	59.xyz	62.xyz	66.xyz	7.xyz	73.xyz	77.xyz	80.xyz	84.xyz	88.xyz	91.xyz
12.xyz	16.xyz	2.xyz	23.xyz	27.xyz	30.xyz	34.xyz	38.xyz	41.xyz	45.xyz	49.xyz	52.xyz	56.xyz	6.xyz	63.xyz	67.xyz	70.xyz	74.xyz	78.xyz	81.xyz	85.xyz	89.xyz	92.xyz

./SiN_raw/Si_Only:
100.xyz  101.xyz  102.xyz  103.xyz  104.xyz  105.xyz  106.xyz  93.xyz  94.xyz  95.xyz  96.xyz  97.xyz  98.xyz  99.xyz

307	SAIT_semiconductors_ACS_2023_HfO_out-of-domain	DS_dixgsms1jm98_0
308	SAIT_semiconductors_ACS_2023_HfO_raw	DS_ekrypue10aay_0
309	SAIT_semiconductors_ACS_2023_HfO_test	DS_dxzkbbocjb0y_0
310	SAIT_semiconductors_ACS_2023_HfO_train	DS_ppk44zeithjj_0
311	SAIT_semiconductors_ACS_2023_HfO_validation	DS_89w2iq8fw7qi_0
312	SAIT_semiconductors_ACS_2023_SiN_out-of-domain	DS_mo7yelvudt4k_0
313	SAIT_semiconductors_ACS_2023_SiN_raw	DS_piuigd7monq9_0
314	SAIT_semiconductors_ACS_2023_SiN_test	DS_orfjpdomkekx_0
315	SAIT_semiconductors_ACS_2023_SiN_train	DS_5yfdgzb5zhgm_0
316	SAIT_semiconductors_ACS_2023_SiN_validation	DS_5piytwom0j25_0"""
move_file(
    "/persistent/colabfit_raw_data/sait/HfO/OOD.xyz",
    "DS_dixgsms1jm98_0",
)
move_file(
    "/persistent/colabfit_raw_data/sait/HfO_raw",
    "DS_ekrypue10aay_0",
)
move_file(
    "/persistent/colabfit_raw_data/sait/HfO/Testset.xyz",
    "DS_dxzkbbocjb0y_0",
)
move_file(
    "/persistent/colabfit_raw_data/sait/HfO/Trainset.xyz",
    "DS_ppk44zeithjj_0",
)
move_file(
    "/persistent/colabfit_raw_data/sait/HfO/Validset.xyz",
    "DS_89w2iq8fw7qi_0",
)
move_file(
    "/persistent/colabfit_raw_data/sait/SiN/OOD.xyz",
    "DS_mo7yelvudt4k_0",
)
move_file(
    "/persistent/colabfit_raw_data/sait/SiN_raw",
    "DS_piuigd7monq9_0",
)
move_file(
    "/persistent/colabfit_raw_data/sait/SiN/Testset.xyz",
    "DS_orfjpdomkekx_0",
)
move_file(
    "/persistent/colabfit_raw_data/sait/SiN/Trainset.xyz",
    "DS_5yfdgzb5zhgm_0",
)
move_file(
    "/persistent/colabfit_raw_data/sait/SiN/Validset.xyz",
    "DS_5piytwom0j25_0",
)

"""

# %%
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/qm_22",
    "DS_2qq05tdbyovn_0",
)
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/aff_jcp_2022",
    "DS_5lhmgnxhuia3_0",
)
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/ag_pbe_msmse_2021",
    "DS_6e5ljaqa3cfr_0",
)

move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/au_pbe_msmse_2021",
    "DS_tydu7u0h0hhz_0",
)
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/c7h10o2",
    "DS_olmzgsz9hmxy_0",
)
"""
72	CA-9_BB_training	DS_l7inbtql4ea9_0
73	CA-9_BB_validation	DS_8zft35i5sbgd_0
74	CA-9_BR_training	DS_fw7m5d8b0fa9_0
75	CA-9_BR_validation	DS_fgakfcwhn9zc_0
76	CA-9_RR_training	DS_tag5zubl21w8_0
77	CA-9_RR_validation	DS_mr2qaiqh2sx2_0
78	CA-9_test	DS_h0mshvvbxlai_0
79	CA-9_training	DS_9cdtww9pcjqd_0
80	CA-9_validation	DS_07zjrtacjg3z_0

BB_training.db	BB_validation.db  BR_training.db  BR_validation.db  CA-9.db  CA-9_training.db  CA-9_validation.db  RR_training.db  RR_validation.db  test_images.db
"""

move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/ca_9/ca_9_data/datasets/BB_training.db",
    "DS_l7inbtql4ea9_0",
)
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/ca_9/ca_9_data/datasets/BB_validation.db",
    "DS_8zft35i5sbgd_0",
)
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/ca_9/ca_9_data/datasets/BR_training.db",
    "DS_fw7m5d8b0fa9_0",
)
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/ca_9/ca_9_data/datasets/BR_validation.db",
    "DS_fgakfcwhn9zc_0",
)
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/ca_9/ca_9_data/datasets/RR_training.db",
    "DS_tag5zubl21w8_0",
)
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/ca_9/ca_9_data/datasets/RR_validation.db",
    "DS_mr2qaiqh2sx2_0",
)
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/ca_9/ca_9_data/datasets/test_images.db",
    "DS_h0mshvvbxlai_0",
)
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/ca_9/ca_9_data/datasets/CA-9_training.db",
    "DS_9cdtww9pcjqd_0",
)
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/ca_9/ca_9_data/datasets/CA-9_validation.db",
    "DS_07zjrtacjg3z_0",
)


move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/cohinpt_schaaf/reaction-barriers-mlffs-main/data/training/",
    "DS_l9f0rjjqfd67_0",
)

move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/combat",
    "DS_xs942mj0c3dx_0",
)
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/cu_fhiaims_npjcm_2021/Cu_FHIaims-PBE-dataset.json",
    "DS_39v8vn61tlzl_0",
)
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/das_mlip_comgsb/training_dataset/training_dataset/",
    "DS_eyo7scxvrfq0_0",
)
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/deepmd-se",
    "DS_k85kj1kiekip_0",
)
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/dpgen_cu_cpc_2020/Cu-dpgen/",
    "DS_101uk70asqhq_0",
)
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/gdb9",
    "DS_2s5grfmdez1q_0",
)
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/gfn_xtb_si",
    "DS_0x8ozlt9g3y5_0",
)
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/hfo2_dpgen_prb_2021",
    "DS_qgi1kbtdzwmm_0",
)
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/hfo2_gap",
    "DS_u40eq96ge40x_0",
)
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/ho_combustion",
    "DS_lvixye0ynk1o_0",
)
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/hpt_nc_2022",
    "DS_fhvr3y1alb97_0",
)
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/iso17",
    "DS_ngsaypfb9rnj_0",
)
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/mbgdml",
    "DS_e94my2wrh074_0",
)
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/mg_edmonds_2022",
    "DS_caktb6z8yiy7_0",
)
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/nep_prb_2021",
    "DS_yg0yzoiwoux8_0",
)
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/nequip_nature_2022",
    "DS_4pbhjtu62o2d_0",
)
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/nnip/NNIP-FeH-main/DATABASE/database.data",
    "DS_nb8hcpibz1dt_0",
)
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/nnp_ga2o3",
    "DS_3qumwe2j8lib_0",
)
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/nvnmd",
    "DS_0gyf3srv7xh7_0",
)

move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/qm_hamiltonian",
    "DS_02cqe6a0bobu_0",
)


move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/si_h_gap/Si-H-GAP-main/structural_data/reference_structures.xyz",
    "DS_a3v4bu6mts6b_0",
)
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/si_h_gap/Si-H-GAP-main/structural_data/training",
    "DS_8arvjtldu4fw_0",
)
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/si_h_gap/Si-H-GAP-main/structural_data/validation_structures.xyz",
    "DS_vywqeohskg2j_0",
)
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/simple_nn/SIMPLE-NN/examples/SiO2/ab_initio_output/OUTCAR_comp",
    "DS_w2ngtxl0ep5d_0",
)
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/tds_pdv_atari/data/",
    "DS_yk3t004l8dpd_0",
)
move_file(
    "/persistent/colabfit_raw_data/gw_scripts/gw_script_data/zeo_1",
    "DS_9in0wrvt6qg2_0",
)

# %%
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/fe_nanoparticles_prb_2023/convex_hull.xyz",
    "DS_5h3810yhu4wj_0",
)

move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/discrepencies_error_npj2023/Enhanced_Validation_Set",
    "DS_q6e3bvq4y67a_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/discrepencies_error_npj2023/Interstitial-enhanced_Training_Set",
    "DS_nublbp38wse0_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/discrepencies_error_npj2023/Interstitial-RE_Testing_Set",
    "DS_dhe9aqs9q1wf_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/discrepencies_error_npj2023/Vacancy-enhanced_Training_Set",
    "DS_qxd7wv9yabtp_0",
)
move_file(
    "/persistent/colabfit_raw_data/new_raw_datasets_2.0/discrepencies_error_npj2023/Vacancy-RE_Testing_Set",
    "DS_la08goe2lz0g_0",
)

"""
3BPA_isolated_atoms	DS_gaq0fec8i6ik_0
3BPA_test_1200K	DS_xaasqmrdv28s_0
3BPA_test_300K	DS_i4hwummq4c7j_0
3BPA_test_600K	DS_epqxcavda3kt_0
3BPA_test_dih_beta120	DS_8cg3pdvxt0pa_0
3BPA_test_dih_beta150	DS_199ama4h9t7m_0
3BPA_test_dih_beta180	DS_ilijykl0t0fn_0
3BPA_train_300K	DS_hu0btdblv8x6_0
3BPA_train_mixed	DS_v88913tvdxbr_0

iso_atoms.xyz  test_1200K.xyz  test_300K.xyz  test_600K.xyz	test_dih_beta120.xyz  test_dih_beta150.xyz  test_dih_beta180.xyz  train_300K.xyz  train_mixedT.xyz
"""
move_file(
    "/persistent/colabfit_raw_data/3bpa/iso_atoms.xyz",
    "DS_gaq0fec8i6ik_0",
)
move_file(
    "/persistent/colabfit_raw_data/3bpa/test_1200K.xyz",
    "DS_xaasqmrdv28s_0",
)

move_file(
    "/persistent/colabfit_raw_data/3bpa/test_300K.xyz",
    "DS_i4hwummq4c7j_0",
)
move_file(
    "/persistent/colabfit_raw_data/3bpa/test_600K.xyz",
    "DS_epqxcavda3kt_0",
)
move_file(
    "/persistent/colabfit_raw_data/3bpa/test_dih_beta120.xyz",
    "DS_8cg3pdvxt0pa_0",
)
move_file(
    "/persistent/colabfit_raw_data/3bpa/test_dih_beta150.xyz",
    "DS_199ama4h9t7m_0",
)
move_file(
    "/persistent/colabfit_raw_data/3bpa/test_dih_beta180.xyz",
    "DS_ilijykl0t0fn_0",
)
move_file(
    "/persistent/colabfit_raw_data/3bpa/train_300K.xyz",
    "DS_hu0btdblv8x6_0",
)
move_file(
    "/persistent/colabfit_raw_data/3bpa/train_mixedT.xyz",
    "DS_v88913tvdxbr_0",
)

"""
AENET_amorphous_LiSi_JCP2021	DS_0nnbymlcjota_0
AENET_liquid_water_dataset_JCP2021	DS_v4bk24pq0had_0
"""
move_file(
    "/persistent/colabfit_raw_data/aenet/amorphous-LiSi-PBE",
    "DS_0nnbymlcjota_0",
)
move_file(
    "/persistent/colabfit_raw_data/aenet/liquid-water-revPBE-D3",
    "DS_v4bk24pq0had_0",
)

move_file("/persistent/colabfit_raw_data/aff", "DS_5lhmgnxhuia3_0")
move_file(
    "/persistent/colabfit_raw_data/alcumg_gsfe/20180426_SF_stress_dependence_least",
    "DS_styimm9cal6v_0",
)
move_file(
    "/persistent/colabfit_raw_data/aleatoric",
    "DS_pms72aqfzc4v_0",
)
move_file(
    "/persistent/colabfit_raw_data/alkali_intercalation",
    "DS_mnt5vb22pdze_0",
)
move_file(
    "/persistent/colabfit_raw_data/alniti",
    "DS_dtjyh96dypuu_0",
)
move_file(
    "/persistent/colabfit_raw_data/alpha_brass",
    "DS_agiti2oe5bqb_0",
)

move_file(
    "/persistent/colabfit_raw_data/colabfit_data/data/ANI-1_release/",
    "DS_p4evspy1ntcs_0",
)
move_file(
    "/persistent/colabfit_raw_data/c_gardner",
    "DS_mma0w04wa4cs_0",
)
move_file(
    "/persistent/colabfit_raw_data/carbon_tadmor/carbon_energies_forces",
    "DS_qph0akhjv9kv_0",
)

# %%
move_file(
    "/persistent/colabfit_raw_data/calcium_ferrites",
    "DS_w59koijcczkz_0",
)

move_file(
    "/persistent/colabfit_raw_data/cathode_ca/minerals",
    "DS_s00e64z80ujy_0",
)
move_file(
    "/persistent/colabfit_raw_data/cationic_yttrium/om2c00238_si_001.xyz",
    "DS_y6bp7td4dle0_0",
)


move_file("/persistent/colabfit_raw_data/cg_schnet", "DS_xzaglubh0trq_0")
move_file("/persistent/colabfit_raw_data/cg_schnet", "DS_xzaglubh0trq_0")

# %%
move_file(
    "/persistent/colabfit_raw_data/comp6_v2/COMP6v2-B973c-def2mTZVP.h5",
    "DS_0dbwoxq96gga_0",
)  # COMP6v2-B973c-def2mTZVP.h5
move_file(
    "/persistent/colabfit_raw_data/comp6_v2/COMP6v2-wB97MD3BJ-def2TZVPP.h5",
    "DS_mznjdz4oqv11_0",
)  # COMP6v2-wB97MD3BJ-def2TZVPP COMP6v2-wB97MD3BJ-def2TZVPP.h5
move_file(
    "/persistent/colabfit_raw_data/comp6_v2/COMP6v2-wB97MV-def2TZVPP.h5",
    "DS_m6etjqhlu40m_0",
)  # COMP6v2-wB97MV-def2TZVPP COMP6v2-wB97MV-def2TZVPP.h5
move_file(
    "/persistent/colabfit_raw_data/comp6_v2/COMP6v2_wB97X-631Gd.h5", "DS_15m7etw1om8a_0"
)  # COMP6v2-wB97X-631Gd COMP6v2_wB97X-631Gd.h5

move_file("/persistent/colabfit_raw_data/coco_coupling", "DS_3a3auhtmkv45_0")

move_file("/persistent/colabfit_raw_data/conbv", "DS_sn623uhg2d1b_0")
move_file("/persistent/colabfit_raw_data/cupd", "DS_0ry6z1j8mi8c_0")

move_file(
    "/persistent/colabfit_raw_data/magnetic_mtp/magnetic_mtp_training_set.cfg",
    "DS_mf8sn11cn6wa_0",
)
move_file(
    "/persistent/colabfit_raw_data/magnetic_mtp/magnetic_mtp_verification_set.cfg",
    "DS_wu6xd9i8cf7i_0",
)

# %%
"""
LMNTO-SCAN-train-data  LMNTO-SCAN-validation-data  liquid-64water-AIMD-RPBE-D3-train-test-data	liquid-64water-AIMD-RPBE-D3-validation-data  water-clusters-BLYP-D3
HO_LiMoNiTi_NPJCM_2020_bulk_water_train_test	DS_jjiywlyfpnme_0
HO_LiMoNiTi_NPJCM_2020_bulk_water_validation	DS_w3whk1nr1bld_0
HO_LiMoNiTi_NPJCM_2020_LiMoNiTi_train	DS_1i4q8uyams32_0
HO_LiMoNiTi_NPJCM_2020_LiMoNiTi_validation	DS_fgjil336jos6_0
HO_LiMoNiTi_NPJCM_2020_water_clusters	DS_or3nu4t64mvk_0
HO_PNAS_2019	DS_o73heom14iew_0
"""

move_file(
    "/persistent/colabfit_raw_data/limoniti/liquid-64water-AIMD-RPBE-D3-train-test-data",
    "DS_jjiywlyfpnme_0",
)
move_file(
    "/persistent/colabfit_raw_data/limoniti/liquid-64water-AIMD-RPBE-D3-validation-data",
    "DS_w3whk1nr1bld_0",
)
move_file(
    "/persistent/colabfit_raw_data/limoniti/LMNTO-SCAN-train-data",
    "DS_1i4q8uyams32_0",
)
move_file(
    "/persistent/colabfit_raw_data/limoniti/LMNTO-SCAN-validation-data",
    "DS_fgjil336jos6_0",
)
move_file(
    "/persistent/colabfit_raw_data/limoniti/water-clusters-BLYP-D3",
    "DS_or3nu4t64mvk_0",
)

"""
Transition1x_train	DS_sn0csplf32qj_0
Transition1x-test	DS_zzfaosyakwom_0
Transition1x-validation	DS_ktku4cml3al7_0
"""
move_file(
    "/persistent/colabfit_raw_data/",
    "DS_sn0csplf32qj_0",
)
move_file(
    "/persistent/colabfit_raw_data/",
    "DS_zzfaosyakwom_0",
)
move_file(
    "/persistent/colabfit_raw_data/",
    "DS_ktku4cml3al7_0",
)
"""
Matbench_mp_e_form	DS_5drebe4tktiu_0
Matbench_mp_gap	DS_6lq2f26dluql_0
Matbench_perovskites	DS_sinisy47w8ff_0
"""

move_file(
    "/persistent/colabfit_raw_data/matbench/matbench_mp_e_form.json",
    "DS_5drebe4tktiu_0",
)

move_file(
    "/persistent/colabfit_raw_data/matbench/matbench_mp_gap.json",
    "DS_6lq2f26dluql_0",
)
move_file(
    "/persistent/colabfit_raw_data/matbench/matbench_perovskites.json",
    "DS_sinisy47w8ff_0",
)
"""
GST_GAP_22_extended	DS_efcq7a0h6z5w_0
GST_GAP_22_main	DS_r3hav37ufnmb_0
GST_GAP_22_refitted	DS_jy3ylaf48xg3_0
"""
move_file(
    "/persistent/colabfit_raw_data/gst_gap/1_reference_database/extended_GST-GAP-22_for_efield_PBEsol.xyz",
    "DS_efcq7a0h6z5w_0",
)
move_file(
    "/persistent/colabfit_raw_data/gst_gap/1_reference_database/main_GST-GAP-22_PBEsol.xyz",
    "DS_r3hav37ufnmb_0",
)
move_file(
    "/persistent/colabfit_raw_data/gst_gap/1_reference_database/refitted_GST-GAP-22_PBE.xyz",
    "DS_jy3ylaf48xg3_0",
)

move_file(
    "/persistent/colabfit_raw_data/crconi_cao/Training_Cao_20220823.cfg",
    "DS_z2mkok0egrm8_0",
)

"""
doped_CsPbI3_energetics_test	DS_a2ftwj9b873a_0
doped_CsPbI3_energetics_train_validate	DS_doj9b688juif_0
"""
move_file(
    "/persistent/colabfit_raw_data/cspbi3/both_both_data.pkl",
    "DS_a2ftwj9b873a_0",
)
move_file(
    "/persistent/colabfit_raw_data/cspbi3/both_both_data.pkl",
    "DS_doj9b688juif_0",
)

# %%
"""
Transition1x_train	DS_sn0csplf32qj_0
Transition1x-test	DS_zzfaosyakwom_0
Transition1x-validation	DS_ktku4cml3al7_0
"""

from pathlib import Path

file_location = "/persistent/colabfit_raw_data/transition_1x/Transition.tar.xz"
directories = [
    "/persistent/colabfit_raw_data/data_by_id/DS_sn0csplf32qj_0",
    "/persistent/colabfit_raw_data/data_by_id/DS_zzfaosyakwom_0",
    "/persistent/colabfit_raw_data/data_by_id/DS_ktku4cml3al7_0",
]
move_and_symlink(file_location, directories)

move_file(
    "/persistent/colabfit_raw_data/defected_phosphorene/phosphorene_dataset",
    "DS_k059wtxqsksu_0",
)

move_file(
    "/persistent/colabfit_raw_data/disordered_transition/trajectories",
    "DS_k1k8iul6kgm2_0",
)
move_file(
    "/persistent/colabfit_raw_data/electrode_ca/minerals",
    "DS_swl40hdnt479_0",
)
move_file(
    "/persistent/colabfit_raw_data/ferro_elec",
    "DS_1t2xs8bzygtp_0",
)
move_file(
    "/persistent/colabfit_raw_data/Fe_Linear_NPJ2021",
    "DS_ej5u0tuycoph_0",
)
"""
UNEP_v1_2023_test	DS_jyklsju4h580_0
UNEP_v1_2023_train	DS_14h4rvviya0k_0
"""
move_file(
    "/persistent/colabfit_raw_data/unep/testset",
    "DS_jyklsju4h580_0",
)
move_file(
    "/persistent/colabfit_raw_data/unep/trainset",
    "DS_14h4rvviya0k_0",
)
move_file(
    "/persistent/colabfit_raw_data/glass_ceramic",
    "DS_cpznjcu51bvg_0",
)

move_file(
    "/persistent/colabfit_raw_data/hdnnp/training-data_H2O",
    "DS_in2572v33lon_0",
)

move_file(
    "/persistent/colabfit_raw_data/hea25/HEA25.extxyz",
    "DS_hvx1spm3gmia_0",
)
move_file(
    "/persistent/colabfit_raw_data/hea25s",
    "DS_d5zht3ykr8hi_0",
)
move_file(
    "/persistent/colabfit_raw_data/ho_pnas/training-set",
    "DS_o73heom14iew_0",
)

move_file(
    "/persistent/colabfit_raw_data/h_smnio3",
    "DS_r1sl5dye35kg_0",
)
move_file(
    "/persistent/colabfit_raw_data/fitsnap_data_files/InP_JPCA2020",
    "DS_03ph25s4yepy_0",
)
move_file(
    "/persistent/colabfit_raw_data/fitsnap_data_files/WBe_PRB2019",
    "DS_yq2whjjndyq5_0",
)
move_file(
    "/persistent/colabfit_raw_data/fitsnap_data_files/Ta_Linear_JCP2014",
    "DS_rgtu2lkgv5rq_0",
)

# %%
move_file(
    "/persistent/colabfit_raw_data/linear_magnetic_coeff/archive",
    "DS_82x5bfiiyaij_0",
)
"""
Mo_PRM2019	DS_5aeg7va6k305_0
Nb_PRM2019	DS_tbpx3pawtlgt_0
Ta_PRM2019	DS_40zw467dnc6d_0
V_PRM2019	DS_ouwlietscprn_0
W_PRB2019	DS_gh9s2sopu064_0
"""
move_file(
    "/persistent/colabfit_raw_data/acclab/Mo/",
    "DS_5aeg7va6k305_0",
)
move_file(
    "/persistent/colabfit_raw_data/acclab/Nb/",
    "DS_tbpx3pawtlgt_0",
)
move_file(
    "/persistent/colabfit_raw_data/acclab/Ta/",
    "DS_40zw467dnc6d_0",
)
move_file(
    "/persistent/colabfit_raw_data/acclab/V/",
    "DS_ouwlietscprn_0",
)
move_file(
    "/persistent/colabfit_raw_data/acclab/W/",
    "DS_gh9s2sopu064_0",
)

move_file(
    "/persistent/colabfit_raw_data/litio_science",
    "DS_0pv4lpmx2ov3_0",
)

move_file(
    "/persistent/colabfit_raw_data/lamn03_polariz",
    "DS_t8goqf2uglhj_0",
)
move_file(
    "/persistent/colabfit_raw_data/mispr",
    "DS_rsao7xrpu9ig_0",
)

move_file(
    "/persistent/colabfit_raw_data/monbtavw_2021/db_HEA_reduced.xyz",
    "DS_0shp3qrqk9k9_0",
)
move_file(
    "/persistent/colabfit_raw_data/mtpu_2023",
    "DS_326i4urabisb_0",
)

move_file(
    "/persistent/colabfit_raw_data/ndsc_tut/hcp_Mg_geomopti_randshear_pm_0.01_product_symm_k0p012.extxyz",
    "DS_oqqwzogut1on_0",
)


move_file(
    "/persistent/colabfit_raw_data/nep_qhpf/test/",
    "DS_mc8p14cpn2ea_0",
)
move_file(
    "/persistent/colabfit_raw_data/nep_qhpf/train/",
    "DS_umliq1qh50gy_0",
)

move_file(
    "/persistent/colabfit_raw_data/nicocr_2020/",
    "DS_5tegg4uvaixz_0",
)
move_file(
    "/persistent/colabfit_raw_data/nnp_ga2o3/",
    "DS_3qumwe2j8lib_0",
)

move_file(
    "/persistent/colabfit_raw_data/oxygen_vacancy_cu/",
    "DS_ots0ul69q842_0",
)

move_file(
    "/persistent/colabfit_raw_data/paramagnetic_lanth/",
    "DS_cm3cr5kgqomw_0",
)

"mv Mg_DFT_mechanical.tar.xz ../data_by_id/DS_48yn17885mdi_0/DS_48yn17885mdi_0.tar.xz"

move_file(
    "/persistent/colabfit_raw_data/pwmlff",
    "DS_cgjdk1e2txjy_0",
)
move_file(
    "/persistent/colabfit_raw_data/qm7b",
    "DS_3a5xucj4yqa8_0",
)
move_file(
    "/persistent/colabfit_raw_data/reann",
    "DS_s818rozdb6x6_0",
)

move_file(
    "/persistent/colabfit_raw_data/reduced_perovskite",
    "DS_cl44a8aa0fgb_0",
)
move_file(
    "/persistent/colabfit_raw_data/reduced_perovskite",
    "DS_u7fu1meyxvpc_0",
)
move_file(
    "/persistent/colabfit_raw_data/si_prx_gap",
    "DS_u9wd92plbetq_0",
)

move_file(
    "/persistent/colabfit_raw_data/solute_mg",
    "DS_b4o9n4n8b7sp_0",
)
move_file(
    "/persistent/colabfit_raw_data/sputtered_cuins2",
    "DS_qk4qfeka1e3m_0",
)
move_file(
    "/persistent/colabfit_raw_data/colabfit_data/data/mishin/dataset_Ta_train.dat",
    "DS_r6c6gt2s98xm_0",
)

move_file(
    "/persistent/colabfit_raw_data/colabfit_data/data/gubaev/TiZrHfTa_APS2021/train.cfg",
    "DS_ngso7es93qnj_0",
)

move_file(
    "/persistent/colabfit_raw_data/tsff_plos/journal.pone.0264960.s001.log",
    "DS_a0bxs66goqvv_0",
)


move_file(
    "/persistent/colabfit_raw_data/acta_vanadium",
    "DS_4mjnowmrcqib_0",
)
move_file(
    "/persistent/colabfit_raw_data/water_cu_methanol",
    "DS_kl12pfupgv5e_0",
)
move_file(
    "/persistent/colabfit_raw_data/yttrium_catalyzed/yttrium_catalyzed_si_002.xyz",
    "DS_xrfpxtaioi75_0",
)

move_file(
    "/persistent/colabfit_raw_data/zn_mtp_cms/Zn.cfg",
    "DS_58y020ce6b6j_0",
)
move_file(
    "/persistent/colabfit_raw_data/zrsn/ZrSn.cfg",
    "DS_6woak771jubv_0",
)

move_file(
    "/persistent/colabfit_raw_data/zif",
    "DS_sh7jt3ptmde4_0",
)
move_file(
    "/persistent/colabfit_raw_data/geng_goddard/DFT_outcar",
    "DS_p74559sdjy1q_0",
)

move_file(
    "/persistent/colabfit_raw_data/reactive_hydrogen",
    "DS_apdpxdjx082p_0",
)

# %%
move_file(
    "/persistent/colabfit_raw_data/mlearn/Mo",
    "DS_ytoet4uyc32k_0",
)

move_file(
    "/persistent/colabfit_raw_data/comp6_v2/COMP6v2_wB97X-631Gd.h5",
    "DS_rde4chkdmm18_0",
)


move_file(
    "/persistent/colabfit_raw_data/aissquare/LiGePS-SSE-PBEsol",
    "DS_dhtzh0y2108p_0",
)

move_file(
    "/persistent/colabfit_raw_data/aissquare/agau/AgAu-nanoalloy",
    "DS_t0ec1irmeo59_0",
)
move_file(
    "/persistent/colabfit_raw_data/aissquare/ins2se3/Liugroup",
    "DS_v4e6t79tt5xh_0",
)

move_file(
    "/persistent/colabfit_raw_data/aissquare/sn_scan_dpgen/datasets",
    "DS_h1i3plesx7bc_0",
)

move_file(
    "/persistent/colabfit_raw_data/aissquare/ti_npjcm/Ti",
    "DS_aaocsvp2x40m_0",
)

# %%
# OMat24
"""DS_vxd0mrt5it19_0  OMat24_validation_rattled_300_subsampled
DS_zduxfk2oohzc_0  OMat24_validation_rattled_500
DS_c4s38mdirjf7_0  OMat24_validation_rattled_1000_subsampled
DS_8k237jm1rd3s_0  OMat24_validation_rattled_1000
DS_h7gnyidyqcxe_0  OMat24_validation_rattled_500_subsampled
DS_qrkr2xiw1wtp_0  OMat24_validation_aimd-from-PBE-1000-npt
DS_sng40qq19dak_0  OMat24_validation_aimd-from-PBE-1000-nvt
DS_abagltajle7q_0  OMat24_validation_rattled_relax
DS_mm4npn96qxo1_0  OMat24_validation_rattled_300"""

move_file(
    "/persistent/colabfit_raw_data/omat24/omat_val_data/rattled-300-subsampled",
    "DS_vxd0mrt5it19_0",
)
move_file(
    "/persistent/colabfit_raw_data/omat24/omat_val_data/rattled-500",
    "DS_zduxfk2oohzc_0",
)
move_file(
    "/persistent/colabfit_raw_data/omat24/omat_val_data/rattled-1000-subsampled",
    "DS_c4s38mdirjf7_0",
)
move_file(
    "/persistent/colabfit_raw_data/omat24/omat_val_data/rattled-1000",
    "DS_8k237jm1rd3s_0",
)
move_file(
    "/persistent/colabfit_raw_data/omat24/omat_val_data/rattled-500-subsampled",
    "DS_h7gnyidyqcxe_0",
)
move_file(
    "/persistent/colabfit_raw_data/omat24/omat_val_data/aimd-from-PBE-1000-npt",
    "DS_qrkr2xiw1wtp_0",
)
move_file(
    "/persistent/colabfit_raw_data/omat24/omat_val_data/aimd-from-PBE-1000-nvt",
    "DS_sng40qq19dak_0",
)
move_file(
    "/persistent/colabfit_raw_data/omat24/omat_val_data/rattled-relax",
    "DS_abagltajle7q_0",
)
move_file(
    "/persistent/colabfit_raw_data/omat24/omat_val_data/rattled-300",
    "DS_mm4npn96qxo1_0",
)
move_file(
    "/persistent/colabfit_raw_data/omat24/omat_val_data/aimd-from-PBE-3000-npt",
    "DS_krd83tt1g6wd_0",
)
move_file(
    "/persistent/colabfit_raw_data/omat24/omat_val_data/aimd-from-PBE-3000-nvt",
    "DS_4vdrw3cfi4s7_0",
)

# %% [markdown]
# ## Bottom

# %%
import pandas as pd

pd.set_option("display.max_colwidth", None)
df = pd.read_csv(
    "dataset_name_id_links.csv", names=["name", "id", "links", "file_created"]
).drop(["links", "file_created"], axis=1)
df[df["name"].str.match(r".*nanoparticles.*")]
# Out:
#                   name                 id
# 72    CA-9_BB_training  DS_l7inbtql4ea9_0
# 73  CA-9_BB_validation  DS_8zft35i5sbgd_0
# 74    CA-9_BR_training  DS_fw7m5d8b0fa9_0
# 75  CA-9_BR_validation  DS_fgakfcwhn9zc_0
# 76    CA-9_RR_training  DS_tag5zubl21w8_0
# 77  CA-9_RR_validation  DS_mr2qaiqh2sx2_0
# 78           CA-9_test  DS_h0mshvvbxlai_0
# 79       CA-9_training  DS_9cdtww9pcjqd_0
# 80     CA-9_validation  DS_07zjrtacjg3z_0
